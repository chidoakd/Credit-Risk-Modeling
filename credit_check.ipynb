# %% [markdown]
# ## Credit Analysis
# Process : Analysis -> featue engineering -> Model -> Credit Check App

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# setting display options for better readability
pd.set_option('display.max_columns', None)

# %%
#setting seaborn style
sns.set(style="whitegrid")

# %%
# loading the dataset
df = pd.read_csv('german_credit_data.csv', index_col=0)
df.head()
# Out:
#    Age     Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0   67    male    2     own             NaN           little           1169
# 1   22  female    2     own          little         moderate           5951
# 2   49    male    1     own          little              NaN           2096
# 3   45    male    2    free          little           little           7882
# 4   53    male    2    free          little           little           4870
#
#    Duration              Purpose  Risk
# 0         6             radio/TV  good
# 1        48             radio/TV   bad
# 2        12            education  good
# 3        42  furniture/equipment  good
# 4        24                  car   bad

# %%
# check the accounts risk data distribution
df["Risk"].value_counts()
# Out:
# Risk
# good    700
# bad     300
# Name: count, dtype: int64

# %%
df.shape # data shape
# Out:
# (1000, 10)

# %%
# show basic information about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               1000 non-null   int64
#  1   Sex               1000 non-null   object
#  2   Job               1000 non-null   int64
#  3   Housing           1000 non-null   object
#  4   Saving accounts   817 non-null    object
#  5   Checking account  606 non-null    object
#  6   Credit amount     1000 non-null   int64
#  7   Duration          1000 non-null   int64
#  8   Purpose           1000 non-null   object
#  9   Risk              1000 non-null   object
# dtypes: int64(4), object(6)
# memory usage: 85.9+ KB

# %%
# show statistical summary of numerical features
df.describe(include='all').T
# Out:
#                    count unique     top freq      mean          std    min  \
# Age               1000.0    NaN     NaN  NaN    35.546    11.375469   19.0
# Sex                 1000      2    male  690       NaN          NaN    NaN
# Job               1000.0    NaN     NaN  NaN     1.904     0.653614    0.0
# Housing             1000      3     own  713       NaN          NaN    NaN
# Saving accounts      817      4  little  603       NaN          NaN    NaN
# Checking account     606      3  little  274       NaN          NaN    NaN
# Credit amount     1000.0    NaN     NaN  NaN  3271.258  2822.736876  250.0
# Duration          1000.0    NaN     NaN  NaN    20.903    12.058814    4.0
# Purpose             1000      8     car  337       NaN          NaN    NaN
# Risk                1000      2    good  700       NaN          NaN    NaN
#
#                      25%     50%      75%      max
# Age                 27.0    33.0     42.0     75.0
# ...

# %%
# show NAN summary
df.isna().sum()
# Out:
# Age                   0
# Sex                   0
# Job                   0
# Housing               0
# Saving accounts     183
# Checking account    394
# Credit amount         0
# Duration              0
# Purpose               0
# Risk                  0
# dtype: int64

# %%
# show dublicated rows
df.duplicated().sum()
# Out:
# 0

# %%
# drop NAN values
df = df.dropna().reset_index(drop=True)

# %%
df
# Out:
#      Age     Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0     22  female    2     own          little         moderate           5951
# 1     45    male    2    free          little           little           7882
# 2     53    male    2    free          little           little           4870
# 3     35    male    3    rent          little         moderate           6948
# 4     28    male    3     own          little         moderate           5234
# ..   ...     ...  ...     ...             ...              ...            ...
# 517   48    male    1     own          little         moderate           1743
# 518   30    male    3     own          little           little           3959
# 519   40    male    3     own          little           little           3857
# 520   23    male    2    free          little           little           1845
# 521   27    male    2     own        moderate         moderate           4576
#
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'Job', 'Housing', 'Saving accounts', 'Checking account',
#        'Credit amount', 'Duration', 'Purpose', 'Risk'],
#       dtype='object')

# %%
# show histograms of numerical features
df[["Age", "Credit amount", "Duration"]].hist(bins=7, edgecolor='black')
plt.suptitle('Histograms of Numerical Features', fontsize=16)
plt.show()

# %%
# show boxplots of numerical features for outlier detection
plt.figure(figsize=(10, 5))
for i, col in enumerate(["Age", "Credit amount", "Duration"] ):
    #print (i, col)
    plt.subplot(1, 3, i + 1)
    sns.boxplot(y=df[col], color='skyblue')
    plt.title(f'Boxplot of {col}')

plt.tight_layout()
plt.show()

# %%
# filter rows where Duration is greater than or equal to 60
df.query("Duration >= 60")
# Out:
#      Age     Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 18    63    male    2     own          little           little           6836
# 176   24  female    3     own        moderate         moderate           7408
# 199   60  female    3    free        moderate         moderate          14782
# 358   24    male    2     own        moderate         moderate           5595
# 378   27    male    3     own          little         moderate          14027
# 489   42    male    2    free          little         moderate           6288
# 507   36    male    2    rent          little           little           7297
#
#      Duration          Purpose Risk
# 18         60         business  bad
# 176        60              car  bad
# 199        60  vacation/others  bad
# 358        72         radio/TV  bad
# 378        60              car  bad
# 489        60        education  bad
# 507        60         business  bad

# %%
# identify numerical and categorical columns
# categorical_cols = df.select_dtypes(include=['object']).columns
# numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns
categorical_cols = ["Sex", "Job", "Housing", "Saving accounts", "Checking account", "Purpose"]

# %%
# visualize categorical features with countplots
plt.figure(figsize=(15, 10))
for i, col in enumerate(categorical_cols):
    plt.subplot(3, 3, i + 1)
    sns.countplot(data=df,x=col, hue="Risk", palette="Set2", order=df[col].value_counts().index)
    plt.title(f'Distrubition of {col}')
    plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
# correlation matrix
corr = df[["Age","Job","Credit amount","Duration"]].corr()
corr
# Out:
#                     Age       Job  Credit amount  Duration
# Age            1.000000  0.039771       0.082014  0.001549
# Job            0.039771  1.000000       0.334721  0.200794
# Credit amount  0.082014  0.334721       1.000000  0.613298
# Duration       0.001549  0.200794       0.613298  1.000000

# %%
# heatmap of the correlation matrix
plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, cmap= "coolwarm", fmt=".2f")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# average credit amount by job
df.groupby("Job")["Credit amount"].mean()
# Out:
# Job
# 0    1767.857143
# 1    2250.715517
# 2    3129.130990
# 3    5648.784810
# Name: Credit amount, dtype: float64

# %%
# average credit amount by sex
df.groupby("Sex")["Credit amount"].mean()
# Out:
# Sex
# female    2937.202381
# male      3440.833333
# Name: Credit amount, dtype: float64

# %%
# average credit amount by housing and purpose using pivot table
pd.pivot_table(df, values="Credit amount", index="Housing", columns="Purpose")
# Out:
# Purpose     business          car  domestic appliances    education  \
# Housing
# free     4705.000000  5180.314286                  NaN  5314.250000
# own      3725.973684  3120.485437               1333.5  2625.076923
# rent     6180.833333  3398.285714                  NaN  2627.857143
#
# Purpose  furniture/equipment     radio/TV  repairs  vacation/others
# Housing
# free             4419.444444  2097.000000   1190.0      7842.666667
# own              3031.100000  2307.613861   2993.5     10321.833333
# rent             2890.285714  2138.000000   2384.0              NaN

# %%
sns.scatterplot(data=df, x="Age", y="Credit amount", hue="Sex", size="Duration", alpha=0.7, palette="Set1")
plt.title('Age vs Credit Amount colored by Sex and sized by Duration')
plt.show()

# %%
# violin plot of credit amount by saving accounts
sns.violinplot(data=df, x="Saving accounts", y="Credit amount", palette="Pastel1")
plt.title('Credit Amount Distribution by Saving Accounts')
plt.show()
# Out:
# /var/folders/88/1tqm3g0n6zv6_b8_7dkfs2600000gq/T/ipykernel_4518/3855413595.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x="Saving accounts", y="Credit amount", palette="Pastel1")

# %%
# show the percentage distribution of the target variable 'Risk'
df["Risk"].value_counts(normalize=True)*100
# Out:
# Risk
# good    55.747126
# bad     44.252874
# Name: proportion, dtype: float64

# %%
# boxplots of numerical features grouped by the target variable 'Risk'
plt.figure(figsize=(8, 4)) 
for i, col in enumerate(["Age","Credit amount","Duration"]):
    plt.subplot(1, 3, i + 1)
    sns.boxplot(data=df, x="Risk", y=col, palette="Set3", hue="Risk")
    plt.title(f'{col} Distribution by Risk')

plt.tight_layout()
plt.show()

# %%
# average values of numerical features grouped by the target variable 'Risk'
df.groupby("Risk")[["Age", "Credit amount", "Duration"]].mean()
# Out:
#             Age  Credit amount   Duration
# Risk
# bad   34.147186    3881.090909  25.445887
# good  35.477663    2800.594502  18.079038

# %%
categorical_cols
# Out:
# ['Sex', 'Job', 'Housing', 'Saving accounts', 'Checking account', 'Purpose']

# %%
# Show categorical features distribution by the target variable 'Risk'
plt.figure(figsize=(15, 10))
for i, col in enumerate(categorical_cols):
    plt.subplot(3, 3, i + 1)
    sns.countplot(data=df, x=col, hue="Risk", palette="Set1", order=df[col].value_counts().index)
    plt.title(f"{col} by Risk")
    plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'Job', 'Housing', 'Saving accounts', 'Checking account',
#        'Credit amount', 'Duration', 'Purpose', 'Risk'],
#       dtype='object')

# %%
# define important features for modeling
features =["Age", "Job", "Sex", "Housing", "Saving accounts", "Checking account", "Credit amount", "Duration"]

# %%
# define the  target variable
target = "Risk"

# %%
# define the modeling dataframe
df_model = df[features + [target]].copy()

# %%
df_model.head()
# Out:
#    Age  Job     Sex Housing Saving accounts Checking account  Credit amount  \
# 0   22    2  female     own          little         moderate           5951
# 1   45    2    male    free          little           little           7882
# 2   53    2    male    free          little           little           4870
# 3   35    3    male    rent          little         moderate           6948
# 4   28    3    male     own          little         moderate           5234
#
#    Duration  Risk
# 0        48   bad
# 1        42  good
# 2        24   bad
# 3        36  good
# 4        30   bad
